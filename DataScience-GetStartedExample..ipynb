# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
import mathplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15840\3472640611.py in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import mathplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'mathplotlib'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = {'year ': [
    2010,2011,2012,
    2010,2011,2012,
    2010,2011,2012    
       ],
       'team':[
           'FCBarca','FCBarca','FCBarca',
           'RMadrid','RMadrid','RMadrid',
           'ValenciaFC','ValenciaFC','ValenciaFC'
       ],
       'wins':
           [30,28,32,39,32,26,21,17,19],
        'draws':[6,7,4,5,4,7,8,10,8],
        'loses':[2,3,2,4,2,5,9,11,11]
       }
football = pd.DataFrame(data,columns=['year','team','wins','draws','loses']
                       )

# %%
pd.DataFrame({'A': [1, 2, 3]})
# Out:
#    A
# 0  1
# 1  2
# 2  3

# %%
data = {'year': [
2010, 2011, 2012,
2010, 2011, 2012,
2010, 2011, 2012
] ,
'team': [
'FCBarcelona', 'FCBarcelona',
'FCBarcelona', 'RMadrid',
'RMadrid', 'RMadrid',
'ValenciaCF', 'ValenciaCF',
'ValenciaCF'
] ,
'wins': [30, 28, 32, 29, 32, 26, 21, 17, 19],
'draws': [6, 7, 4, 5, 4, 7, 8, 10, 8],
'losses': [2, 3, 2, 4, 2, 5, 9, 11, 11]
}
football = pd.DataFrame(data , columns = [
'year', 'team', 'wins', 'draws', 'losses'
])

# %%
data = {'year': [
2010, 2011, 2012,
2010, 2011, 2012,
2010, 2011, 2012
] ,
'team': [
'FCBarcelona', 'FCBarcelona',
'FCBarcelona', 'RMadrid',
'RMadrid', 'RMadrid',
'ValenciaCF', 'ValenciaCF',
'ValenciaCF'
] ,
'wins': [30, 28, 32, 29, 32, 26, 21, 17, 19],
'draws': [6, 7, 4, 5, 4, 7, 8, 10, 8],
'losses': [2, 3, 2, 4, 2, 5, 9, 11, 11]
}
football = pd.DataFrame(data , columns = ['year', 'team', 'wins', 'draws', 'losses'])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = {'year': [
2010, 2011, 2012,
2010, 2011, 2012,
2010, 2011, 2012
] ,
'team': [
'FCBarcelona', 'FCBarcelona',
'FCBarcelona', 'RMadrid',
'RMadrid', 'RMadrid',
'ValenciaCF', 'ValenciaCF',
'ValenciaCF'
] ,
'wins': [30, 28, 32, 29, 32, 26, 21, 17, 19],
'draws': [6, 7, 4, 5, 4, 7, 8, 10, 8],
'losses': [2, 3, 2, 4, 2, 5, 9, 11, 11]
}
football = pd.DataFrame(data , columns = ['year', 'team', 'wins', 'draws', 'losses'])

# %%
display(football)
# Out:
#    year         team  wins  draws  losses
# 0  2010  FCBarcelona    30      6       2
# 1  2011  FCBarcelona    28      7       3
# 2  2012  FCBarcelona    32      4       2
# 3  2010      RMadrid    29      5       4
# 4  2011      RMadrid    32      4       2
# 5  2012      RMadrid    26      7       5
# 6  2010   ValenciaCF    21      8       9
# 7  2011   ValenciaCF    17     10      11
# 8  2012   ValenciaCF    19      8      11

# %%
football.describe()
# Out:
#               year       wins      draws     losses
# count     9.000000   9.000000   9.000000   9.000000
# mean   2011.000000  26.000000   6.555556   5.444444
# std       0.866025   5.656854   2.006932   3.844188
# min    2010.000000  17.000000   4.000000   2.000000
# 25%    2010.000000  21.000000   5.000000   2.000000
# 50%    2011.000000  28.000000   7.000000   4.000000
# 75%    2012.000000  30.000000   8.000000   9.000000
# max    2012.000000  32.000000  10.000000  11.000000

# %%
football['wins']
# Out:
# 0    30
# 1    28
# 2    32
# 3    29
# 4    32
# 5    26
# 6    21
# 7    17
# 8    19
# Name: wins, dtype: int64

# %%
football
# Out:
#    year         team  wins  draws  losses
# 0  2010  FCBarcelona    30      6       2
# 1  2011  FCBarcelona    28      7       3
# 2  2012  FCBarcelona    32      4       2
# 3  2010      RMadrid    29      5       4
# 4  2011      RMadrid    32      4       2
# 5  2012      RMadrid    26      7       5
# 6  2010   ValenciaCF    21      8       9
# 7  2011   ValenciaCF    17     10      11
# 8  2012   ValenciaCF    19      8      11

# %%
display(football)
# Out:
#    year         team  wins  draws  losses
# 0  2010  FCBarcelona    30      6       2
# 1  2011  FCBarcelona    28      7       3
# 2  2012  FCBarcelona    32      4       2
# 3  2010      RMadrid    29      5       4
# 4  2011      RMadrid    32      4       2
# 5  2012      RMadrid    26      7       5
# 6  2010   ValenciaCF    21      8       9
# 7  2011   ValenciaCF    17     10      11
# 8  2012   ValenciaCF    19      8      11

# %%
football=football.append({"year":2022,"team":"PSG","wins":30,"draws":3,"losses":14},ignore_index=True)
football
# Out:
# C:\Users\ashut\AppData\Local\Temp\ipykernel_21852\3187388777.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   football=football.append({"year":2022,"team":"PSG","wins":30,"draws":3,"losses":14},ignore_index=True)
#    year         team  wins  draws  losses
# 0  2010  FCBarcelona    30      6       2
# 1  2011  FCBarcelona    28      7       3
# 2  2012  FCBarcelona    32      4       2
# 3  2010      RMadrid    29      5       4
# 4  2011      RMadrid    32      4       2
# 5  2012      RMadrid    26      7       5
# 6  2010   ValenciaCF    21      8       9
# 7  2011   ValenciaCF    17     10      11
# 8  2012   ValenciaCF    19      8      11
# 9  2022          PSG    30      3      14

# %%
football
# Out:
#    year         team  wins  draws  losses
# 0  2010  FCBarcelona    30      6       2
# 1  2011  FCBarcelona    28      7       3
# 2  2012  FCBarcelona    32      4       2
# 3  2010      RMadrid    29      5       4
# 4  2011      RMadrid    32      4       2
# 5  2012      RMadrid    26      7       5
# 6  2010   ValenciaCF    21      8       9
# 7  2011   ValenciaCF    17     10      11
# 8  2012   ValenciaCF    19      8      11
# 9  2022          PSG    30      3      14

# %%
football=football.drop(9)

# %%
football
# Out:
#    year         team  wins  draws  losses
# 0  2010  FCBarcelona    30      6       2
# 1  2011  FCBarcelona    28      7       3
# 2  2012  FCBarcelona    32      4       2
# 3  2010      RMadrid    29      5       4
# 4  2011      RMadrid    32      4       2
# 5  2012      RMadrid    26      7       5
# 6  2010   ValenciaCF    21      8       9
# 7  2011   ValenciaCF    17     10      11
# 8  2012   ValenciaCF    19      8      11

# %%
football=football.drop(3,axis='index')

# %%
display(football)
# Out:
#    year         team  wins  draws  losses
# 0  2010  FCBarcelona    30      6       2
# 1  2011  FCBarcelona    28      7       3
# 2  2012  FCBarcelona    32      4       2
# 3  2010      RMadrid    29      5       4
# 4  2011      RMadrid    32      4       2
# 5  2012      RMadrid    26      7       5
# 6  2010   ValenciaCF    21      8       9
# 7  2011   ValenciaCF    17     10      11
# 8  2012   ValenciaCF    19      8      11

# %%
football.sort_index(axis=0,ascending=True,inplace=True)

# %%
football
# Out:
#    year         team  wins  draws  losses
# 0  2010  FCBarcelona    30      6       2
# 1  2011  FCBarcelona    28      7       3
# 2  2012  FCBarcelona    32      4       2
# 3  2010      RMadrid    29      5       4
# 4  2011      RMadrid    32      4       2
# 5  2012      RMadrid    26      7       5
# 6  2010   ValenciaCF    21      8       9
# 7  2011   ValenciaCF    17     10      11
# 8  2012   ValenciaCF    19      8      11

# %%
group=football[['year','team','wins','losses','draws']].groupby('team').max()
group
# Out:
#              year  wins  losses  draws
# team
# FCBarcelona  2012    32       3      7
# RMadrid      2012    32       5      7
# ValenciaCF   2012    21      11     10

# %%
football
# Out:
#    year         team  wins  draws  losses
# 0  2010  FCBarcelona    30      6       2
# 1  2011  FCBarcelona    28      7       3
# 2  2012  FCBarcelona    32      4       2
# 3  2010      RMadrid    29      5       4
# 4  2011      RMadrid    32      4       2
# 5  2012      RMadrid    26      7       5
# 6  2010   ValenciaCF    21      8       9
# 7  2011   ValenciaCF    17     10      11
# 8  2012   ValenciaCF    19      8      11

# %%
piv=pd.pivot_table(football,values="wins",
                  index=["team"],
                  columns=["year"])
piv
# Out:
# year         2010  2011  2012
# team
# FCBarcelona    30    28    32
# RMadrid        29    32    26
# ValenciaCF     21    17    19

# %%
piv.loc[["FCBarcelona"],[2010,2011]]
# Out:
# year         2010  2011
# team
# FCBarcelona    30    28

# %%
piv.rank(ascending=False)
# Out:
# year         2010  2011  2012
# team
# FCBarcelona   1.0   2.0   1.0
# RMadrid       2.0   1.0   2.0
# ValenciaCF    3.0   3.0   3.0

# %%
piv
# Out:
# year         2010  2011  2012
# team
# FCBarcelona    30    28    32
# RMadrid        29    32    26
# ValenciaCF     21    17    19

# %%
tot_sum=piv.sum(axis=1)
tot_sum.rank(ascending=False)
# Out:
# team
# FCBarcelona    1.0
# RMadrid        2.0
# ValenciaCF     3.0
# dtype: float64

# %%
tot_sum
# Out:
# team
# FCBarcelona    90
# RMadrid        87
# ValenciaCF     57
# dtype: int64

# %%
tot_sum.plot(kind="bar",style='r',alpha=1,title="TOTAL WINS")
# Out:
# <AxesSubplot:title={'center':'TOTAL WINS'}, xlabel='team'>

# %%
football.plot(kind="bar",style='r',alpha=1,title="TOTAL WINS")
# Out:
# <AxesSubplot:title={'center':'TOTAL WINS'}>

# %%
fy=football.drop("year",axis=1)
fy
fy.plot(kind="barh",stacked=True)
# Out:
# <AxesSubplot:>

# %%
co=['r','k','y']
p=piv.plot(kind="barh",color=co,stacked=True)
p.legend(loc="best",bbox_to_anchor=(1,1))

# %%
football.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21852\4148987751.py in <module>
# ----> 1 football.shape()
#
# TypeError: 'tuple' object is not callable

# %%
fy.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21852\3203871410.py in <module>
# ----> 1 fy.shape()
#
# TypeError: 'tuple' object is not callable

# %%
f.shape()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21852\1603468907.py in <module>
# ----> 1 f.shape()
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
group.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21852\1981874284.py in <module>
# ----> 1 group.shape()
#
# TypeError: 'tuple' object is not callable
